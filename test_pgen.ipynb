# %%
from pgenlib_tools import PgenReaderFull


ANGPTL3 = PgenReaderFull(pfile_path="test/ukb_wes_chr9")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from pgenlib_tools import PgenReaderFull
#       4 ANGPTL3 = PgenReaderFull(pfile_path="test/ukb_wes_chr9")
#
# File /data/share/xutingfeng/ukbwes/pgen_tools/pgenlib_tools/__init__.py:2
#       1 __version__ = "0.1"
# ----> 2 from .tools import PgenReaderFull
#
# File /data/share/xutingfeng/ukbwes/pgen_tools/pgenlib_tools/tools.py:4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import pgenlib as pg
#       8 def read_pvar(pvar):
#       9     comment_lines = check_comment_lines(pvar)
#
# ModuleNotFoundError: No module named 'pgenlib'

# %%
# %%time
import numpy as np 
random_snp_idx = [int(i) for i in set(list(np.random.randint(0, ANGPTL3.get_variant_ct(), 10000)))]
geno_array, snpid, sample_id = ANGPTL3.extract(variant_idx=random_snp_idx)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Out:
# [342016,
#  442370,
#  450564,
#  530438,
#  505863,
#  743432,
#  278539,
#  557072,
#  942097,
#  215058,
#  159762,
#  692244,
#  329749,
#  405524,
#  8220,
#  733214,
#  127012,
#  847909,
#  92200,
#  438316,
#  182317,
#  432174,
#  950318,
#  174125,
#  585777,
#  567346,
#  356401,
#  712756,
#  673844,
#  213040,
#  299062,
#  571446,
#  477242,
#  653370,
#  675900,
#  935999,
#  467008,
#  4159,
#  43074,
#  458821,
#  712775,
#  282696,
#  163917,
#  41038,
#  548945,
#  338003,
#  667733,
#  888920,
#  784474,
#  655451,
#  933980,
#  823386,
#  942170,
#  938077,
#  407649,
#  725089,
#  718951,
#  505961,
#  893036,
#  809076,
#  462964,
#  290935,
#  667769,
#  75899,
#  219263,
#  458880,
#  505989,
#  503942,
#  706693,
#  934030,
#  483470,
#  776336,
#  307347,
#  852118,
#  47255,
#  745623,
#  333981,
#  434335,
#  555168,
#  786599,
#  295079,
#  73897,
#  716968,
#  815275,
#  600241,
#  630963,
#  549044,
#  604341,
#  843957,
#  219317,
#  424116,
# ...
